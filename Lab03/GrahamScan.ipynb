# %% [markdown]
# ## Graham Scan Algorithm
# *by Mohammad Akbar*

# %% [markdown]
# ***
# Import some stuff

# %%
from PVClass import Graph, Point

# %% [markdown]
# ***
# plot our points

# %%
# %reset -f
from PVClass import Graph, Point
x1 = [0, 1, 2, 4, 0, 1, 3, 3,1,2,5,4,8,3,8]
y1 = [3, 1, 2, 4, 0, 2, 1, 3,8,1,4,7,4,6,8]
G1 = Graph(x1,y1)
bl1 = G1.bottom_left()
G1.sort_ccw(bl1)
G1.scan()
print(G1)
G1.plot2(False,True,True)
# Out:
# ( 0 , 0 ),( 3 , 1 ),( 8 , 4 ),( 8 , 8 ),( 1 , 8 ),( 0 , 3 )

# %%
# %reset -f
from PVClass import Graph, Point
x2 = [0, 2, 1, 2, 3, 0, 3]
y2 = [3, 2, 1, 1, 0, 0, 3]
G2 = Graph(x2,y2)
bl2 = G2.bottom_left()
G2.sort_ccw(bl2)
G2.scan()
print(G2)
G2.plot2(False,True,True);
# Out:
# ( 0 , 0 ),( 3 , 0 ),( 3 , 3 ),( 0 , 3 )

# %%
# %reset -f
from PVClass import Graph, Point
x3 = [3, 2, 2, 2, 3, 1, 1]
y3 = [1, 3, 4, 5, 7, 2, 6]
G3 = Graph(x3,y3)
bl3 = G3.bottom_left()
G3.sort_ccw(bl3)
G3.scan()
print(G3)
G3.plot2(False,True,True);
# Out:
# ( 3 , 1 ),( 3 , 7 ),( 1 , 6 ),( 1 , 2 )
