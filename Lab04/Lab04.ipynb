# %% [markdown]
# **Andrew's monotone chain convex hull algorithm**<br>
# *by Mohammad Akbar*

# %% [markdown]
# *python already uses double precision floats*

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mpl.style.use('fivethirtyeight')

# %%
from GraphClass import Graph

# %%
x = [0, 1, 2, 4,0, 1, 3, 3]
y = [3, 1, 2, 4,0, 2, 1, 3]
G = Graph(x,y,"Test Case: Example 1")
C = G.ConvexHull()
G.plot()
print(C)
# Out:
# [( 0 , 0 ), ( 3 , 1 ), ( 4 , 4 ), ( 0 , 3 )]

# %%
x = [0, 2, 1, 2, 3, 0, 3]
y = [3, 2, 1, 1, 0, 0, 3]
G = Graph(x,y,"Test Case: Example 2")
C = G.ConvexHull()
G.plot()
print(C)
# Out:
# [( 0 , 0 ), ( 3 , 0 ), ( 3 , 3 ), ( 0 , 3 )]

# %%
x = [3, 2, 2, 2, 3, 1, 1]
y = [1, 3, 4, 5, 7, 2, 6]
G = Graph(x,y,"Test Case: Example 3")
C = G.ConvexHull()
G.plot()
print(C)
# Out:
# [( 1 , 2 ), ( 3 , 1 ), ( 3 , 7 ), ( 1 , 6 )]

# %%
x = [0, 0, 0, 2, 1, 2, 3, 0, 3, 2, 4]
y = [3, 1, 2, 2, 1, 1, 0, 0, 3, 4, 2]
G = Graph(x,y,"Test Case: Additional")
C = G.ConvexHull()
G.plot()
print(C)
# Out:
# [( 0 , 0 ), ( 3 , 0 ), ( 4 , 2 ), ( 3 , 3 ), ( 2 , 4 ), ( 0 , 3 ), ( 0 , 2 ), ( 0 , 1 )]
